# %%
# Write a loop that calculates the same result as 5 ** 3 using multiplication (and without exponentiation).
a=5
for i in range(2):
    a=a*5
    print a
# Out:
# 25
# 125

# %%
# Write a loop that takes a string, and produces a new string with the characters in reverse order,
# so 'Newton' becomes 'notweN'.
string1='Newton'
string1[::-1]
# Out:
# 'notweN'

# %%
# Use a for-loop to convert the string “hello” into a list of letters
string2='hello'
string_list=[]
for i in range(len(string2)):
    string_list.append(string2[i])
print string_list
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
import glob
print(glob.glob('../data_python/*.csv'))
# Out:
# ['../data_python/inflammation-02.csv', '../data_python/inflammation-03.csv', '../data_python/inflammation-04.csv', '../data_python/inflammation-05.csv', '../data_python/inflammation-06.csv', '../data_python/inflammation-07.csv', '../data_python/inflammation-08.csv', '../data_python/inflammation-09.csv', '../data_python/inflammation-10.csv', '../data_python/inflammation-11.csv', '../data_python/inflammation-12.csv', '../data_python/small-01.csv', '../data_python/small-02.csv', '../data_python/small-03.csv']

# %%
import numpy
import matplotlib.pyplot
# %matplotlib inline

filenames = glob.glob('../data_python/*.csv')
filenames = filenames[0:3]
for f in filenames:
    print(f)

    data = numpy.loadtxt(fname=f, delimiter=',')

    fig = matplotlib.pyplot.figure(figsize=(10.0, 3.0))

    axes1 = fig.add_subplot(1, 3, 1)
    axes2 = fig.add_subplot(1, 3, 2)
    axes3 = fig.add_subplot(1, 3, 3)

    axes1.set_ylabel('average')
    axes1.plot(data.mean(axis=0))

    axes2.set_ylabel('max')
    axes2.plot(data.max(axis=0))

    axes3.set_ylabel('min')
    axes3.plot(data.min(axis=0))

    fig.tight_layout()
    matplotlib.pyplot.show(fig)
# Out:
# ../data_python/inflammation-02.csv
# ../data_python/inflammation-03.csv
# ../data_python/inflammation-04.csv

# %%
# Test whether are not increasing suspiciosly
data = numpy.loadtxt(fname='inflammation-01.csv', delimiter=',')
if data.max(axis=0)[0] == 0 and data.max(axis=0)[20] == 20:
    print('Suspicious looking maxima!')
elif data.min(axis=0).sum() == 0:
    print('Minima add up to zero!')
else:
    print('Seems OK!')
# Out:
# Suspicious looking maxima!

# %%
data = numpy.loadtxt(fname='../data_python/inflammation-03.csv', delimiter=',')
if data.max(axis=0)[0] == 0 and data.max(axis=0)[20] == 20:
    print('Suspicious looking maxima!')
elif data.min(axis=0).sum() == 0:
    print('Minima add up to zero!')
else:
    print('Seems OK!')
# Out:
# Minima add up to zero!

# %%
if 4 > 5:
    print('A')
elif 4 == 5:
    print('B')
elif 4 < 5:
    print('C')
# Out:
# C

# %%
#True and False are special words in Python called booleans which represent true and false statements. 
# However, they aren’t the only values in Python that are true and false. In fact, any value can be used in
# an if or elif. 
# After reading and running the code below, explain what the rule is for which values are considered true and 
# which are considered false.

if '':
    print('empty string is true')
if 'word':
    print('word is true')
if []:
    print('empty list is true')
if [1, 2, 3]:
    print('non-empty list is true')
if 0:
    print('zero is true')
if 1:
    print('one is true')
# Out:
# word is true
# non-empty list is true
# one is true

# %% [markdown]
# Write some conditions that print True if the variable a is within 10% of the variable b and False otherwise.
# Compare your implementation with your partner’s: do you get the same answer for all possible pairs of numbers?

# %%
a=2
b=10
if a <= b/10:
    print 'True'
else:
    print 'False'
# Out:
# False

# %% [markdown]
# Write some code that sums the positive and negative numbers in a list separately, using in-place operators.
# Do you think the result is more or less readable than writing the same without in-place operators?

# %%
x=1
l=[]
for i in range(5):
    x+=8
    l.append(x)
print l
# Out:
# [9, 17, 25, 33, 41]

# %%
x=-1
l=[]
for i in range(5):
    x+=-8
    l.append(x)
print l
# Out:
# [-9, -17, -25, -33, -41]

# %%
#Explain what the overall effect of this code is:

left = 'L'
right = 'R'
temp = left
left = right
right = temp
print left, right
# Out:
# R L

# %%
# Compare it to:
left = 'L'
right = 'R'
left, right = right, left
print left, right
# Do they always do the same thing? Which do you find easier to read?
# Out:
# R L

# %% [markdown]
# # Creating Functions

# %%
def fahr_to_kelvin(temp):
    return ((temp - 32) * (float(5)/9)) + 273.15

# %%
print'freezing point of water:', fahr_to_kelvin(32)
print'boiling point of water:', fahr_to_kelvin(212)
# Out:
# freezing point of water: 273.15
# boiling point of water: 273.15

# %%
def kelvin_to_celsius(temp):
    return temp - 273.15

print'absolute zero in Celsius:', kelvin_to_celsius(0.0)
# Out:
# absolute zero in Celsius: -273.15

# %%
def fahr_to_celsius(temp):
    temp_k = fahr_to_kelvin(temp)
    result = kelvin_to_celsius(temp_k)
    return result

print'freezing point of water in Celsius:', fahr_to_celsius(32.0)
# Out:
# freezing point of water in Celsius: 0.0

# %%
import numpy
import matplotlib.pyplot
# %matplotlib inline
# Create function to generate plots
def analyze(filename):

    data = numpy.loadtxt(fname=filename, delimiter=',')

    fig = matplotlib.pyplot.figure(figsize=(10.0, 3.0))

    axes1 = fig.add_subplot(1, 3, 1)
    axes2 = fig.add_subplot(1, 3, 2)
    axes3 = fig.add_subplot(1, 3, 3)

    axes1.set_ylabel('average')
    axes1.plot(data.mean(axis=0))

    axes2.set_ylabel('max')
    axes2.plot(data.max(axis=0))

    axes3.set_ylabel('min')
    axes3.plot(data.min(axis=0))

    fig.tight_layout()
    matplotlib.pyplot.show(fig)

# %%
# Create function to detect problems with minima and maxima
def detect_problems(filename):

    data = numpy.loadtxt(fname=filename, delimiter=',')

    if data.max(axis=0)[0] == 0 and data.max(axis=0)[20] == 20:
        print('Suspicious looking maxima!')
    elif data.min(axis=0).sum() == 0:
        print('Minima add up to zero!')
    else:
        print('Seems OK!')

# %%
# Combine two functions
for f in filenames[:3]:
    print(f)
    analyze(f)
    detect_problems(f)
# Out:
# ../data_python/inflammation-02.csv
# Suspicious looking maxima!
# ../data_python/inflammation-03.csv
# Minima add up to zero!
# ../data_python/inflammation-04.csv
# Suspicious looking maxima!

# %%
def center(data, desired):
    return (data - data.mean()) + desired

# %%
def center(data, desired):
    '''Return a new array containing the original data centered around the desired value.
    Example: center([1, 2, 3], 0) => [-1, 0, 1]'''
    return (data - data.mean()) + desired

help(center)
# Out:
# Help on function center in module __main__:
#
# center(data, desired)
#     Return a new array containing the original data centered around the desired value.
#     Example: center([1, 2, 3], 0) => [-1, 0, 1]
